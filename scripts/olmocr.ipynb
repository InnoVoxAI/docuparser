# %% [markdown]
# https://www.youtube.com/watch?v=38loqDtlLok
#
# https://olmocr.allenai.org/blog
#
# https://github.com/allenai/olmocr
#
# https://colab.research.google.com/drive/1X8gEx89lqLvFl9ENmXqGGCcIWi7WqcIA?usp=sharing
#
# https://ollama.com/richardyoung/olmocr2
#
# https://huggingface.co/blog/ggml-org/using-ocr-models-with-llama-cpp
